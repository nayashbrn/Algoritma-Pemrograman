# %% [markdown]
# <a href="https://colab.research.google.com/github/nayashbrn/Algoritma-Pemrograman/blob/main/Inayah_Cikal_Nurshabrina_Praktikum_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PRAKTIKUM 01 - SEQUENTIAL SEARCH PADA DATA ANGKA**

# %%
def sequential_search(data, target):
  for i in range(len(data)):
    if data[i] == target:
      return f"Data {target} ditemukan di indeks {i}"
  return f"Data {target} tidak ditemukan"

angka = [10, 20,30,40,50]
print("Data:", angka)
print(sequential_search(angka, 30))
print(sequential_search(angka, 100))
# Out:
# Data: [10, 20, 30, 40, 50]
# Data 30 ditemukan di indeks 2
# Data 100 tidak ditemukan

# %% [markdown]
# # **PRAKTIKUM 02 - BINARY SEARCH PADA DATA ANGKA**

# %%
def binary_search(data, target):
  left, right = 0, len(data)-1
  while left <= right:
    mid = (left + right) // 2
    if data[mid] == target:
      return f"Data {target} ditemukan di indeks {mid}"
    elif data[mid] < target:
      left = mid + 1
    else:
      right = mid - 1
  return f"Data {target} tidak ditemukan"

angka = [10, 20, 30, 40, 50]
print ("Data:", angka)
print(binary_search(angka, 40))
print(binary_search(angka, 100))
# Out:
# Data: [10, 20, 30, 40, 50]
# Data 40 ditemukan di indeks 3
# Data 100 tidak ditemukan

# %% [markdown]
# # **PRAKTIKUM 03 - SEQUENTIAL SEARCH UNTUK DATA NAMA**

# %%
def sequential_search_nama(data, target):
  for i in range(len(data)):
    if data[i].lower() == target.lower():
      return f"Nama {target} ditemukan di indeks {i}"
  return f"Nama {target} tidak ditemukan"

nama = ["Andi", "Budi", "Cici", "Doni"]
print("Data:", nama)
print(sequential_search_nama(nama, "Cici"))
print(sequential_search_nama(nama, "Eka"))
# Out:
# Data: ['Andi', 'Budi', 'Cici', 'Doni']
# Nama Cici ditemukan di indeks 2
# Nama Eka tidak ditemukan

# %% [markdown]
# # **PRAKTIKUM 04 - STUDI KASUS NILAI MAHASISWA DENGAN BINARY SEARCH**

# %%
def binary_search_nilai(data, target):
  left, right = 0, len(data)-1
  while left <= right:
    mid = (left + right) // 2
    if data[mid] == target:
      return f"Nilai {target} ditemukan di indeks {mid}"
    elif data[mid] < target:
      left = mid + 1
    else:
      right = mid - 1
  return f"Nilai {target} tidak ditemukan"

nilai = [60, 70, 75, 80, 85, 90]
print("Data nilai:", nilai)
print(binary_search_nilai(nilai, 85))
print(binary_search_nilai(nilai, 65))
# Out:
# Data nilai: [60, 70, 75, 80, 85, 90]
# Nilai 85 ditemukan di indeks 4
# Nilai 65 tidak ditemukan

# %% [markdown]
# # **PRAKTIKUM 05 - PERBANDINGAN WAKTU SEQUENTIAL VS BINARY SEARCH**

# %%
import time

def sequential_search(data, target):
  for i in range(len(data)):
    if data[i] == target:
      return i
    return -1

def binary_search(data, target):
  left, right = 0, len(data)-1
  while left <= right:
    mid = (left + right) // 2
    if data[mid] == target:
      return mid
    elif data[mid] < target:
      left = mid + 1
    else:
      right = mid - 1
  return - 1

data = list(range(1, 100001))
target = 99999

start = time.time()
sequential_search(data, target)
end = time.time()
print("Sequential Search waktu:", end - start, "detik")

start = time.time()
binary_search(data, target)
end = time.time()
print("Binary Search waktu:", end - start, "detik")
# Out:
# Sequential Search waktu: 0.00010991096496582031 detik
# Binary Search waktu: 0.0001049041748046875 detik

# %% [markdown]
# # **PRAKTIKUM 06 - KOMBINASI SORTING DAN SEARCHING**

# %%
import random

def insertion_sort(data):
  for i in range(1, len(data)):
    key = data[i]
    j = i - 1
    while j >= 0 and data [j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data

def binary_search(data, target):
  left, right = 0, len(data)-1
  while left <= right:
    mid = (left + right) // 2
    if data[mid] == target:
      return f"{target} ditemukan di indeks {mid}"
    elif data[mid] < target:
      left = mid + 1
    else:
      right = mid - 1
  return f"{target} tidak ditemukan"

data = [random.randint(1, 100) for _ in range(15)]
print("Data acak sebelum diurutkan:", data)
urut = insertion_sort(data)
print("Data setelah diurutkan:", urut)
target = urut[7] #ambil angka ke-8 sebagai target
print(binary_search(urut, target))
# Out:
# Data acak sebelum diurutkan: [98, 78, 99, 30, 39, 52, 27, 66, 47, 53, 46, 1, 55, 84, 7]
# Data setelah diurutkan: [1, 7, 27, 30, 39, 46, 47, 52, 53, 55, 66, 78, 84, 98, 99]
# 52 ditemukan di indeks 7

# %% [markdown]
# # **PENUGASAN 01 - VARIASI SEQUENTIAL SEARCH**

# %%
def sequential_search(data, target):
    perbandingan = 0

    for i in range(len(data)):
        perbandingan += 1  #menghitung setiap perbandingan
        if data[i] == target:
            return f"Data {target} ditemukan di indeks {i} setelah {perbandingan} kali perbandingan"

    return f"Data {target} tidak ditemukan setelah {perbandingan} kali perbandingan"


angka = [10, 20, 30, 40, 50]
print("Data:", angka)

print(sequential_search(angka, 30))
print(sequential_search(angka, 100))
# Out:
# Data: [10, 20, 30, 40, 50]
# Data 30 ditemukan di indeks 2 setelah 3 kali perbandingan
# Data 100 tidak ditemukan setelah 5 kali perbandingan

# %% [markdown]
# # **PENUGASAN 02 - VARIASI BINARY SEARCH**

# %%
def binary_search(data, target):
    left, right = 0, len(data) - 1
    langkah = 0  # menghitung jumlah langkah (iterasi)

    while left <= right:
        langkah += 1
        mid = (left + right) // 2

        if data[mid] == target:
            return f"Data {target} ditemukan di indeks {mid} setelah {langkah} langkah"
        elif data[mid] < target:
            left = mid + 1
        else:
            right = mid - 1

    return f"Data {target} tidak ditemukan setelah {langkah} langkah"


angka = [10, 20, 30, 40, 50]
print("Data:", angka)
print(binary_search(angka, 40))
print(binary_search(angka, 100))
# Out:
# Data: [10, 20, 30, 40, 50]
# Data 40 ditemukan di indeks 3 setelah 2 langkah
# Data 100 tidak ditemukan setelah 3 langkah

# %% [markdown]
# # **PENUGASAN 03 - STUDI KASUS NAMA MAHASISWA**

# %%
# input daftar mahasiswa
n = int(input("Masukkan jumlah mahasiswa: "))

nama_mahasiswa = []
for i in range(n):
    nama = input(f"Masukkan nama mahasiswa ke-{i+1}: ")
    nama_mahasiswa.append(nama)

# input nama yang ingin dicari
target = input("\nMasukkan nama yang ingin dicari: ")

# proses sequential Search
def sequential_search(data, target):
    for i in range(len(data)):
        if data[i].lower() == target.lower():  # agar tidak case-sensitive
            return f"Nama '{target}' ditemukan di indeks {i}"
    return f"Nama '{target}' tidak ditemukan di dalam daftar"

print("\nDaftar Nama Mahasiswa:", nama_mahasiswa)
print(sequential_search(nama_mahasiswa, target))
# Out:
# Masukkan jumlah mahasiswa: 3
# Masukkan nama mahasiswa ke-1: Naya
# Masukkan nama mahasiswa ke-2: Cecil
# Masukkan nama mahasiswa ke-3: Yoni
#
# Masukkan nama yang ingin dicari: Cecil
#
# Daftar Nama Mahasiswa: ['Naya', 'Cecil', 'Yoni']
# Nama 'Cecil' ditemukan di indeks 1

# %% [markdown]
# # **PENUGASAN 04 - STUDI KASUS BARANG TOKO**

# %%
def binary_search_harga(data, target):
    left, right = 0, len(data) - 1
    langkah = 0

    while left <= right:
        langkah += 1
        mid = (left + right) // 2

        # Membandingkan berdasarkan index harga
        if data[mid][1] == target:
            return f"Barang dengan harga {target} ditemukan: {data[mid]} (ditemukan dalam {langkah} langkah)"
        elif data[mid][1] < target:
            left = mid + 1
        else:
            right = mid - 1

    return f"Barang dengan harga {target} tidak ditemukan (dicari dalam {langkah} langkah)"


# Daftar Barang
barang = [
    ("Kopi", 15000),
    ("Cookies", 5000),
    ("Cokelat Klasik", 12000),
    ("Brownies", 20000),
    ("Roti", 8000)
]

# Urutkan berdasarkan harga
barang_sorted = sorted(barang, key=lambda x: x[1])

# Menampilkan hasil sorting
print("=== Daftar Barang Setelah Diurutkan Berdasarkan Harga ===")
for item in barang_sorted:
    print(item)

# Cari harga yang ditentukan
target = int(input("\nMasukkan harga yang ingin dicari: "))

print(binary_search_harga(barang_sorted, target))
# Out:
# === Daftar Barang Setelah Diurutkan Berdasarkan Harga ===
# ('Cookies', 5000)
# ('Roti', 8000)
# ('Cokelat Klasik', 12000)
# ('Kopi', 15000)
# ('Brownies', 20000)
#
# Masukkan harga yang ingin dicari: 8000
# Barang dengan harga 8000 ditemukan: ('Roti', 8000) (ditemukan dalam 3 langkah)

# %% [markdown]
# # **PENUGASAN 05 - ANALISIS KOMPLEKSITAS**

# %%
import time
import random

# Sequential Search
def sequential_search(data, target):
    for item in data:
        if item == target:
            return True
    return False

# Binary Search
def binary_search(data, target):
    left, right = 0, len(data) - 1
    while left <= right:
        mid = (left + right) // 2
        if data[mid] == target:
            return True
        elif data[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return False

# Untuk mengukur waktu
def ukur_waktu(data_size):
    data = list(range(data_size))  # data sudah terurut untuk binary search
    target = random.choice(data)   # memilih target acak di dalam list

    # Sequential Search
    start = time.time()
    sequential_search(data, target)
    waktu_seq = time.time() - start

    # Binary Search
    start = time.time()
    binary_search(data, target)
    waktu_bin = time.time() - start

    return waktu_seq, waktu_bin

# Pengujian untuk ukuran data
ukuran_data = [100, 1000, 10000]
hasil = []

print("=== HASIL PENGUKURAN WAKTU ===")
for size in ukuran_data:
    w_seq, w_bin = ukur_waktu(size)
    hasil.append((size, w_seq, w_bin))
    print(f"Data {size}: Sequential = {w_seq:.6f}s | Binary = {w_bin:.6f}s")
# Out:
# === HASIL PENGUKURAN WAKTU ===
# Data 100: Sequential = 0.000003s | Binary = 0.000004s
# Data 1000: Sequential = 0.000031s | Binary = 0.000005s
# Data 10000: Sequential = 0.000148s | Binary = 0.000006s

# %% [markdown]
# # **PENUGASAN 06 - PROYEK MINI**

# %%
# Binary Search berdasarkan nilai
def binary_search(data, target):
    left, right = 0, len(data) - 1
    langkah = 0

    while left <= right:
        langkah += 1
        mid = (left + right) // 2

        if data[mid][1] == target:
            return mid, langkah   # kembalikan indeks + langkah
        elif data[mid][1] < target:
            left = mid + 1
        else:
            right = mid - 1

    return -1, langkah

# Program Utama
mahasiswa = []
n = int(input("Masukkan jumlah mahasiswa: "))

# Input data mahasiswa
for i in range(n):
    print(f"\nMahasiswa ke-{i+1}")
    nama = input("Nama  : ")
    nilai = int(input("Nilai : "))
    mahasiswa.append((nama, nilai))

# Urutkan berdasarkan nilai (ascending)
mahasiswa_sorted = sorted(mahasiswa, key=lambda x: x[1])

print("\n=== Data Mahasiswa Setelah Diurutkan (berdasarkan Nilai) ===")
for m in mahasiswa_sorted:
    print(f"{m[0]} - {m[1]}")

# Input nilai yang ingin dicari
target = int(input("\nMasukkan nilai yang ingin dicari: "))

# Binary search
index, langkah = binary_search(mahasiswa_sorted, target)

# Tampilkan hasil
print("\n=== HASIL PENCARIAN ===")
if index != -1:
    nama, nilai = mahasiswa_sorted[index]
    print(f"Nilai {target} ditemukan pada mahasiswa: {nama}")
    print(f"Ditemukan pada indeks: {index}")
    print(f"Jumlah langkah binary search: {langkah}")
else:
    print(f"Nilai {target} tidak ditemukan.")
    print(f"Binary search dilakukan dalam {langkah} langkah.")
# Out:
# Masukkan jumlah mahasiswa: 3
#
# Mahasiswa ke-1
# Nama  : Naya
# Nilai : 98
#
# Mahasiswa ke-2
# Nama  : Cecil
# Nilai : 84
#
# Mahasiswa ke-3
# Nama  : Yoni
# Nilai : 72
#
# === Data Mahasiswa Setelah Diurutkan (berdasarkan Nilai) ===
# Yoni - 72
# Cecil - 84
# Naya - 98
#
# Masukkan nilai yang ingin dicari: 98
#
# === HASIL PENCARIAN ===
# Nilai 98 ditemukan pada mahasiswa: Naya
# Ditemukan pada indeks: 2
# Jumlah langkah binary search: 2
