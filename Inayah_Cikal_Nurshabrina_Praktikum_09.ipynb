# %% [markdown]
# <a href="https://colab.research.google.com/github/nayashbrn/Algoritma-Pemrograman/blob/main/Inayah_Cikal_Nurshabrina_Praktikum_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PAKTIKUM 01 - MENGGUNAKAN MODUL math**

# %%
import math

angka = 16
hasil1 = math.sqrt(angka)
hasil2 = math.pow(2,5)
print("Akar kuadrat dari", angka, "=", hasil1)
print("2 pangkat 5 =", hasil2)
# Out:
# Akar kuadrat dari 16 = 4.0
# 2 pangkat 5 = 32.0

# %% [markdown]
# # **PRAKTIKUM 02 - MENGGUNAKAN from ... import...**

# %%
from math import sqrt

angka = 25
hasil = sqrt(angka)
print("Akar kuadrat dari", angka, "=", hasil)
# Out:
# Akar kuadrat dari 25 = 5.0

# %% [markdown]
# # **PRAKTIKUM 03 - MEMBERI ALIAS MODUL**

# %%
import numpy as np

data = np.array([1,2,3])
print("Isi array =", data)
# Out:
# Isi array = [1 2 3]

# %% [markdown]
# # **PRAKTIKUM 04 - EKSPLORASI math, random, dan sys**

# %%
import math
import random
import sys

hasil1 = math.sqrt(81)
hasil2 = random.randint(1,10)
versi = sys.version

print("Akar kuadrat 81 =", hasil1)
print("Angka acak 1-10 =", hasil2)
print("Versi Python =", versi)
# Out:
# Akar kuadrat 81 = 9.0
# Angka acak 1-10 = 3
# Versi Python = 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# # **PRAKTIKUM 05 - MEMBUAT MODUL SENDIRI**

# %%
#Kode Python (modulku.py):
# %%writefile modulku.py
def halo(nama):
    print(f"Halo, {nama}! Selamat belajar Python di Polines.")
# Out:
# Writing modulku.py

# %%
#Kode Python (praktikum09_modul_sendiri.py):
import modulku

modulku.halo("Mahasiswa Polines")
# Out:
# Halo, Mahasiswa Polines! Selamat belajar Python di Polines.

# %% [markdown]
# # **PRAKTIKUM 06 - INSTALASI MODUL DENGAN pip**

# %%
# !pip install requests
import requests

response = requests.get("https://www.polines.ac.id")
print("Status code:", response.status_code)
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Status code: 403

# %% [markdown]
# # **PENUGASAN 01 - EKSPERIMEN DENGAN MODUL math**

# %%
import math
def luas_lingkaran(r):
    return math.pi * r * r

print("Luas lingkaran dengan r = 7 :", luas_lingkaran(7))
print("Luas lingkaran dengan r = 10:", luas_lingkaran(10))
# Out:
# Luas lingkaran dengan r = 7 : 153.93804002589985
# Luas lingkaran dengan r = 10: 314.1592653589793

# %% [markdown]
# # **PENUGASAN 02 - EKSPERIMEN DENGAN MODUL random**

# %%
import random

print("5 Angka acak dari 1–100:")
for i in range(5):
    angka = random.randint(1, 100)
    print(angka)
# Out:
# 5 Angka acak dari 1–100:
# 32
# 82
# 27
# 28
# 63

# %% [markdown]
# # **PENUGASAN 03 - MODUL sys**

# %%
import sys

print("---Informasi Sistem---")
print("Platform :", sys.platform)
print("Versi Python :", sys.version)
# Out:
# ---Informasi Sistem---
# Platform : linux
# Versi Python : 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# # **PENUGASAN 04 - MODUL BUATAN SENDIRI**

# %%
# konversi.py
# %%writefile konversi.py
def celcius_ke_fahrenheit(c):
    return (c * 9/5) + 32

def fahrenheit_ke_celcius(f):
    return (f - 32) * 5/9
# Out:
# Writing konversi.py

# %%
# main.py
import konversi

c = 30
f = 86

print(f"{c}°C = {konversi.celcius_ke_fahrenheit(c)}°F")
print(f"{f}°F = {konversi.fahrenheit_ke_celcius(f)}°C")
# Out:
# 30°C = 86.0°F
# 86°F = 30.0°C

# %% [markdown]
# # **PENUGASAN 05 - INSTALASI LIBRARY PIHAK KETIGA**

# %%
# !pip install pandas
import pandas as pd

data = {
    "NIM": ["4.33.25.1.10", "4.33.25.1.20", "4.33.25.1.10"],
    "Nama": ["Cikal", "Cecil", "Brina"],
    "Prodi": ["TI", "IK", "AK"]
}

# Membuat DataFrame
df = pd.DataFrame(data)

# Menampilkan DataFrame
print(df)
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#             NIM   Nama Prodi
# 0  4.33.25.1.10  Cikal    TI
# 1  4.33.25.1.20  Cecil    IK
# 2  4.33.25.1.10  Brina    AK

# %% [markdown]
# # **PENUGASAN 06 - STUDI KASUS MINI**

# %%
# %%writefile laporan.py

def cetak_laporan(skor, total_soal):
    print("\n--- KUIS SELESAI ---")
    print(f"Skor Anda: {skor} dari {total_soal} soal.")

    #Hitung persentase
    persentase = (skor / total_soal) * 100
    print(f"Nilai Akhir: {persentase:.1f}")

    if persentase == 100:
        print("Selamat! Anda mendapat nilai sempurna.")
    elif persentase >= 70:
        print("Bagus, Anda berhasil!")
    else:
        print("Mohon maaf, Anda belum berhasil.")
# Out:
# Overwriting laporan.py

# %%
import random
import laporan

print("=== KUIS PENJUMLAHAN SEDERHANA ===")
print("Jawablah 3 soal berikut:")

skor = 0
total_soal = 3

for i in range(total_soal):
    a = random.randint(1, 10)
    b = random.randint(1, 10)
    jawaban_benar = a + b

    try:
        jawaban_user = int(input(f"\nSoal {i+1}: {a} + {b} = "))

        if jawaban_user == jawaban_benar:
            print("Jawaban Anda benar!")
            skor += 1
        else:
            print(f"Salah. Jawaban yang benar adalah {jawaban_benar}.")
    except ValueError:
        print("Input tidak valid. Soal ini dianggap salah.")

laporan.cetak_laporan(skor, total_soal)
# Out:
# === KUIS PENJUMLAHAN SEDERHANA ===
# Jawablah 3 soal berikut:
#
# Soal 1: 3 + 9 = 12
# Jawaban Anda benar!
#
# Soal 2: 10 + 6 = 16
# Jawaban Anda benar!
#
# Soal 3: 2 + 5 = 7
# Jawaban Anda benar!
#
# --- KUIS SELESAI ---
# Skor Anda: 3 dari 3 soal.
# Nilai Akhir: 100.0
# Selamat! Anda mendapat nilai sempurna.
